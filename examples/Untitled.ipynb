# %%
import networkx as nx
from littleballoffur import DiffusionSampler
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
graph= nx.newman_watts_strogatz_graph(100, 5, 0.05)
graph

# %%
nx.adjacency_matrix(graph)
# Out:
# <100x100 sparse array of type '<class 'numpy.int64'>'
# 	with 416 stored elements in Compressed Sparse Row format>

# %%
nx.draw(graph)

# %%
sampler = DiffusionSampler()
new_graph = sampler.sample(graph)

# %%
nx.adjacency_matrix(new_graph)
# Out:
# <100x100 sparse array of type '<class 'numpy.int64'>'
# 	with 416 stored elements in Compressed Sparse Row format>

# %%
nx.draw(new_graph)

# %%
sampler.sample?
